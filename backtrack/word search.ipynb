# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def exist(board, word):
    rows, cols = len(board), len(board[0])
    
    def backtrack(r, c, index):
        if index == len(word):
            return True
        if r < 0 or r >= rows or c < 0 or c >= cols or board[r][c] != word[index]:
            return False
        
        # Mark as visited
        temp = board[r][c]
        board[r][c] = '#'
        
        # Explore neighbors
        found = (backtrack(r+1, c, index+1) or
                 backtrack(r-1, c, index+1) or
                 backtrack(r, c+1, index+1) or
                 backtrack(r, c-1, index+1))
        
        # Backtrack (unmark)
        board[r][c] = temp
        return found
    
    for r in range(rows):
        for c in range(cols):
            if backtrack(r, c, 0):
                return True
    return False

# %%
class Solution(object):
    def findMin(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        left = 0
        right = len(nums) - 1

        while left < right:
            mid = (left + right) // 2

            # If mid element is greater than the rightmost element,
            # the minimum is in the right half
            if nums[mid] > nums[right]:
                left = mid + 1
            else:
                # Otherwise, the minimum is in the left half (including mid)
                right = mid

        # After the loop, left == right, pointing to the minimum element
        return nums[left]

# Example usage
sol = Solution()
print(sol.findMin([4, 5, 6, 7, 0, 1, 2]))
# Out:
# 0

# %%
class Solution(object):
    def fizzBuzz(self, n):
        """
        :type n: int
        :rtype: List[str]
        """
        res = []
        for i in range(1,n+1):
            if i%3 == 0 and i%5==0:
                res.append('FizzBuzz')
            elif i%3 == 0:
                res.append('Fizz')
            elif i%5 == 0:
                res.append('Buzz')
            else: res.append(str(i))

        return res

sol = Solution()
print(sol.fizzBuzz(5))
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz']

# %%
class Solution(object):
    def addDigits(self, num):
        """
        :type num: int
        :rtype: int
        """
        return 1 + (num-1)%9

sol = Solution()
print(sol.addDigits(4))
# Out:
# 4

# %%
class Solution:
    def search(self ,nums, target):
        left = 0
        right = len(nums)-1

        while left < right:
            mid = (left+right) //2

            # check if trgt equal mid
            if target == nums[mid]:
                return mid
            
            # check if the left side is sorted
            if nums[left] <= nums[mid]:
                if nums[left] <= target < nums[mid]:
                    right = mid - 1
                else: 
                    left = mid - 1

            # check if the right side is sorted
            else:
                if nums[mid] <= target < nums[right]:
                    left = mid + 1
                else:
                    right = mid -1
        return -1
    

sol = Solution()
print(sol.search(nums = [4,5,6,7,0,1,2], target = 0))
# Out:
# 4

# %%
class Solution(object):
    def search(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: int
        """
        left = 0
        right = len(nums) - 1

        while left <= right:
            mid = (left + right) // 2

            if nums[mid] == target:
                return mid

            # Check if the left half is sorted
            if nums[left] <= nums[mid]:
                if nums[left] <= target < nums[mid]:
                    right = mid - 1
                else:
                    left = mid + 1
            # Otherwise, the right half is sorted
            else:
                if nums[mid] < target <= nums[right]:
                    left = mid + 1
                else:
                    right = mid - 1

        return -1

# Example usage
sol = Solution()
print(sol.search(nums=[4, 5, 6, 7, 0, 1, 2], target=1))

# %%
class Solution(object):
    def arrayPairSum(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        nums.sort()
        return sum(nums[i] for i in range(0, len(nums), 2))
        
sol = Solution()
print(sol.arrayPairSum([1,4,3,2]))
# Out:
# 4

# %%
class Solution(object):
    def summaryRanges(self, nums):
        """
        :type nums: List[int]
        :rtype: List[str]
        """
        res = []
        i = 0
        while i < (len(nums)):
            start = nums[i]
            while i+1 < len(nums) and nums[i] + 1 == nums[i+1]:
                i +=1

            end = nums[i]
            if start == end:
                res.append(str(end))
            
            else:
                res.append(f"{start}->{end}")
            i +=1
        return res
            
sol = Solution()
print(sol.summaryRanges([1,3,4,5]))
# Out:
# ['1', '3->5']

# %% [markdown]
# [1,2,4,5,6 ] -> [1,2], [4,5,6]
#
# we start from the left-most number because that is the smallest number
#     continous = []
#     left = 0
#     # right = len(nums)-1
#
# we add the smallest number in the by 1, if it is in the list of nums, add it as continous.
#     if not, we skip it. then make a new array, and add the next continous list

# %%
right = 6
nums = 0
for i in range(right):
    nums += 1
    print(nums)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
class Solution:
    def firstBadVersion(self):
        # if isBadVersion is false, ingnore it and proceed with only true bool

        isBad = {'3':'false', '5':'true', '4':'true'}
        res = []

        for key, val in isBad.items():
            if val == 'true':
                res.append(key)

        res.sort()
        return res[0]
    
solution = Solution()
print(solution.firstBadVersion())
# Out:
# 4

# %%
def isBadVersion(self):
        pass
class Solution:
    def firstBadVersion(self, n):
        left = 0
        right = n
        while left < right:
            mid = (left+right) //2
            if isBadVersion(mid) == True:
                right = mid
            else:left = mid+1
        return left
