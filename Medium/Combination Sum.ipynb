# %% [markdown]
# Given an array of distinct integers candidates and a target integer target, return a list of all unique combinations of candidates where the chosen numbers sum to target. You may return the combinations in any order.
#
# The same number may be chosen from candidates an unlimited number of times. Two combinations are unique if the
# frequency
#  of at least one of the chosen numbers is different.
#
# The test cases are generated such that the number of unique combinations that sum up to target is less than 150 combinations for the given input.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
class Solution():
    def combinationSum(self, nums, target):
        def backtrack(index, current, sum_comb):
            # a copy from the current result
            # Base Case target reached
            # print(backtrack)
            print(f"combination{current}, = {sum_comb}")
            # print(sum_comb)
            if sum_comb == target:                
                result.append(current[:])
                return
            # Target exceeded
            if sum_comb > target:
                return

            for i in range(index, len(nums)):
                
                ''''if nums[i]+nums[i+1] != target: # hemmm this is not it
                    # keep adding that element until it is equal to target. But how?
                    # do I need another empty array that keep append the i?
                    continue
                '''
                current.append(nums[i])
                backtrack(i, current, sum_comb + nums[i])
                
                # pop the last element and try another combination
                current.pop()
                # how about the duplicates?
        
        result = []
        # nums.sort()
        backtrack(0, [], 0)
        return result

solution = Solution()
print(solution.combinationSum([2,3,5],8))
# Out:
# combination[], = 0
# combination[2], = 2
# combination[2, 2], = 4
# combination[2, 2, 2], = 6
# combination[2, 2, 2, 2], = 8
# combination[2, 2, 2, 3], = 9
# combination[2, 2, 2, 5], = 11
# combination[2, 2, 3], = 7
# combination[2, 2, 3, 3], = 10
# combination[2, 2, 3, 5], = 12
# combination[2, 2, 5], = 9
# combination[2, 3], = 5
# combination[2, 3, 3], = 8
# combination[2, 3, 5], = 10
# combination[2, 5], = 7
# combination[2, 5, 5], = 12
# combination[3], = 3
# combination[3, 3], = 6
# combination[3, 3, 3], = 9
# combination[3, 3, 5], = 11
# combination[3, 5], = 8
# combination[5], = 5
# combination[5, 5], = 10
# [[2, 2, 2, 2], [2, 3, 3], [3, 5]]
