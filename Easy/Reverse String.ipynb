# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution(object):
    def reverseString(self, s):
        """
        :type s: List[str]
        :rtype: None Do not return anything, modify s in-place instead.
        """
        return s[::-1]


solution = Solution()
print(solution.reverseString(["h","e","l","l","o"]))
# Out:
# ['o', 'l', 'l', 'e', 'h']

# %%
class Solution(object):
    def reverseString(self, s):
        """
        :type s: List[str]
        :rtype: None Do not return anything, modify s in-place instead.
        """
        first= 0
        last = len(s)-1
        while first < last:
            temp = s[first]
            s[first] = s[last]
            s[last] = temp

            first += 1
            last -= 1

        return s
        
solution = Solution()
print(solution.reverseString(["h","e","l","l","o"]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 22
#      19         return s
#      21 solution = Solution()
# ---> 22 print(solution.reverseString(["h","e","l","l","o"]))
#
# Cell In[11], line 12, in Solution.reverseString(self, s)
#       9 for i in range(len(s)):
#      10     for j in range(len(s)-1):
# ---> 12         temp = s[i]
#      13         s[i] = s[j]
#      14         s[j] = temp
#
# IndexError: list index out of range
