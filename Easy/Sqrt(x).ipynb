# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution(object):
    def mySqrt(self, x):
        """
        :type x: int
        :rtype: int
        """
        return int(x ** 0.5)
    
solution = Solution()
print(solution.mySqrt(4))
# Out:
# 2
